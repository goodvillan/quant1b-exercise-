# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('dataset.xlsx')
df
# Out:
#       Unnamed: 0    participant_ID  age     sex  exercise_hours_weekly  \
# 0              0     participant_0   36    male                    2.3
# 1              1     participant_1   42    male                    1.5
# 2              2     participant_2   29  female                    2.0
# 3              3     participant_3   57  female                    1.6
# 4              4     participant_4   56    male                    1.4
# ...          ...               ...  ...     ...                    ...
# 3995        3995  participant_3995   38  female                    1.3
# 3996        3996  participant_3996   31    male                    0.8
# 3997        3997  participant_3997   30  female                    1.3
# 3998        3998  participant_3998   59    male                    2.1
# 3999        3999  participant_3999   51    male                    1.1
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# ...

# %% [markdown]
# #### Basic Infomation about Data

# %%
# columns names
df.columns
# Out:
# Index(['Unnamed: 0', 'participant_ID', 'age', 'sex', 'exercise_hours_weekly',
#        'relationship_status', 'income', 'five_a_day_fruit_veg', 'residence',
#        'profession', 'neuroticism', 'openness', 'extraversion',
#        'agreeableness', 'conscientiousness', 'religion', 'GP_visits_last_year',
#        'positive_mental_health_scale'],
#       dtype='object')

# %%
# remove columns with unnamed columns names
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %% [markdown]
# ## Q1

# %% [markdown]
# ### 1) Describe Statistic Summary For each Variable

# %% [markdown]
# * Stastics Summary for Numerical data

# %%
df.describe().T
# Out:
#                                count          mean           std        min  \
# age                           4000.0     42.158750     14.922926  16.000000
# exercise_hours_weekly         4000.0      1.508475      0.433645   0.000000
# income                        4000.0  84758.275250  31307.848742   0.000000
# neuroticism                   4000.0      3.323406      0.787089   0.962246
# openness                      4000.0      4.601641      0.835964   0.000000
# extraversion                  4000.0      3.255688      0.826938   1.000000
# agreeableness                 4000.0      3.742917      0.612059   1.000000
# conscientiousness             4000.0      3.669000      0.697884   1.222222
# GP_visits_last_year           4000.0      3.987500      1.886726   0.000000
# positive_mental_health_scale  4000.0     14.108750      4.765197   0.000000
#
#                                        25%           50%            75%  \
# ...

# %% [markdown]
# * Stastics Summary for Categorical data

# %%
df.describe(include = 'O').T
# Out:
#                      count unique                  top  freq
# participant_ID        4000   4000        participant_0     1
# sex                   4000      3                 male  1925
# relationship_status   4000      5    legal_partnership  2019
# five_a_day_fruit_veg  4000      5               always  1304
# residence             4000      4                urban  1109
# profession            4000      4              skilled  1061
# religion              4000      3  religious_no_church  1528

# %% [markdown]
# ### 2) Provide Visualization with appropriate plot

# %% [markdown]
# * For categorical data we can use bar plot or pie chart
# * if we have more than 4 to 5 categories then it would be great to use bar chart, otherwise pie chart.
# * For numerical data,we can use box plot or histogram plot

# %%
sns.boxplot(df["age"])
plt.show()

# %% [markdown]
# ##### Observation:
# * The above graph shows the minimum age limit is probabily 16 and maximum is near 68.
# * the average age is almost 43

# %%
df['sex'].value_counts().plot(kind = 'pie', autopct='%.0f%%')
plt.show()

# %% [markdown]
# ##### Observation
# * males 48% and females 46% are almost equally represented
# * others are 6%

# %%
sns.boxplot(df['exercise_hours_weekly'])
plt.show()

# %% [markdown]
# ##### Observation:
# * the minimum exercise_hours_weekly limit is probabily 0.3 and maximum is near 2.7.
# * the average exercise_hours_weekly is 1.5

# %%
df['relationship_status'].value_counts().plot(kind = 'bar')
plt.ylabel('count')
plt.show()

# %%
sns.set(rc={'figure.figsize':(11.7,6)})
sns.boxplot(df['income'])
plt.show()

# %% [markdown]
# ##### Observation:
# * The above graph shows the minimum income limit is probabily 0 and maximum is near £170000.
# * the average income is £80,000.

# %%
df['five_a_day_fruit_veg'].value_counts().plot(kind = 'bar')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### Observation
#
# * always is the top value of five_a_day_fruit_veg
# * the rest of the data is almost equally distributed

# %%
df['residence'].value_counts().plot(kind = 'pie', autopct='%.0f%%')
plt.show()

# %% [markdown]
# ##### Observation
# * most people are living in urban areas
# * suburban , rural and town are having same percentage( equally distributed data)

# %%
df['profession'].value_counts().plot(kind = 'pie', autopct='%.0f%%')
plt.show()

# %%
sns.boxplot(df['neuroticism'])
plt.show()

# %% [markdown]
# ##### Observation:
# * the minimum neuroticism limit is probabily 1.2 and maximum is near 5.
# * the average neuroticism is almost 3.4

# %%
sns.boxplot(df['openness'])
plt.show()

# %% [markdown]
# ##### Observation:
# * most people are open to experience(between 4.2 and 5)
# * lots of outliers before the minimum range appear evenly distributed between 0 to 4.2

# %%
sns.boxplot(df['extraversion'])
plt.show()

# %% [markdown]
# ##### Observation:
# * most people scored in the middle for extraversion

# %%
sns.boxplot(df['agreeableness'])
plt.show()

# %% [markdown]
# ##### Observation:
# * the average is almost 3.7 with more people in the dataset showing traits of agreableness

# %%
sns.boxplot(df['conscientiousness'])
plt.show()

# %% [markdown]
# ##### Observation:
# * most people tend to be on the more concientousness half

# %%
df['religion'].value_counts().plot(kind = 'pie', autopct='%.0f%%')
plt.show()

# %% [markdown]
# ##### Observation
#
# * almost evenly distributed data

# %%
sns.boxplot(df['GP_visits_last_year'])
plt.show()

# %% [markdown]
# ##### Observation:
# *  most GP_visits_last_year were between 0 and 8.
# * the average GP_visits_last_year were around 4

# %%
sns.boxplot(df['positive_mental_health_scale'])
plt.show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### 1) Relate a categorical to numerical variables

# %% [markdown]
# * bar charts are a good representation when we have both categorical and numerical variables

# %% [markdown]
# #### Average income of each profession

# %%
df.groupby(['profession'])['income'].mean().plot(kind = 'bar')
plt.ylabel('Average income')
plt.show()

# %% [markdown]
# #### Average income by Residence

# %%
df.groupby(['residence'])['income'].mean().plot(kind = 'bar')
plt.ylabel('Average income')
plt.show()

# %% [markdown]
# ##### Average age  vs five_a_day_fruit_veg

# %%
df.groupby(['five_a_day_fruit_veg'])['age'].mean().plot(kind = 'bar')
plt.ylabel('Average age')
plt.show()

# %% [markdown]
# #### 2)  Relate a categorical to a categorical variable

# %% [markdown]
# * Relationship status with respect to residence

# %%
df.groupby(['relationship_status'])['residence'].value_counts().unstack().plot(kind  = 'bar')
plt.ylabel('residence count')
plt.show()

# %% [markdown]
# ##### * Gender vs residence

# %%
df.groupby(['residence'])['sex'].value_counts().unstack().plot(kind  = 'bar')
plt.ylabel('sex count')
plt.show()

# %% [markdown]
# ##### profession of each gender

# %%
df.groupby(['profession'])['sex'].value_counts().unstack().plot(kind  = 'bar')
plt.ylabel('sex count')
plt.show()

# %% [markdown]
# ##### Religious status of each profession

# %%
df.groupby(['religion'])['profession'].value_counts().unstack().plot(kind  = 'bar')
plt.ylabel('profession count')
plt.show()

# %% [markdown]
# #### 3) Numerical to numerical variables

# %% [markdown]
# ##### income impact the mental health?

# %%
sns.scatterplot(data=df, x="income", y="positive_mental_health_scale")
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### identify the variables!

# %% [markdown]
# * income directly impacts the mental health scale

# %%
df.corr()[['positive_mental_health_scale']]
# Out:
#                               positive_mental_health_scale
# age                                               0.009850
# exercise_hours_weekly                             0.404768
# income                                            0.773351
# neuroticism                                      -0.000738
# openness                                          0.233951
# extraversion                                      0.002889
# agreeableness                                    -0.028165
# conscientiousness                                -0.006150
# GP_visits_last_year                               0.007633
# positive_mental_health_scale                      1.000000

# %% [markdown]
# #### Variables that impact on GP_visits_last_year

# %%
df.corr()[['GP_visits_last_year']]
# Out:
#                               GP_visits_last_year
# age                                      0.267750
# exercise_hours_weekly                    0.000863
# income                                   0.005811
# neuroticism                              0.783678
# openness                                 0.019519
# extraversion                             0.017476
# agreeableness                           -0.028576
# conscientiousness                       -0.003080
# GP_visits_last_year                      1.000000
# positive_mental_health_scale             0.007633

# %% [markdown]
# * According to correlation neuroticism directly impacts the number of GP_visits_last_year.
# * verify it by visualization:

# %%
sns.scatterplot(data=df, x="neuroticism", y="GP_visits_last_year")
plt.show()

# %% [markdown]
# *  Neuroticism directly impacts GP_visits_last_year.

# %% [markdown]
# #### a) men

# %%
df.loc[(df['sex'] == 'male'),:]
# Out:
#         participant_ID  age   sex  exercise_hours_weekly  \
# 0        participant_0   36  male                    2.3
# 1        participant_1   42  male                    1.5
# 4        participant_4   56  male                    1.4
# 8        participant_8   37  male                    1.7
# 10      participant_10   19  male                    0.8
# ...                ...  ...   ...                    ...
# 3990  participant_3990   24  male                    1.8
# 3993  participant_3993   54  male                    2.0
# 3996  participant_3996   31  male                    0.8
# 3998  participant_3998   59  male                    2.1
# 3999  participant_3999   51  male                    1.1
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# 0     long-term_relationship   90998               always      town
# 1     long-term_relationship   82144               rarely  suburban
# 4     long-term_relationship   55091               rarely  suburban
# ...

# %% [markdown]
# #### b) people with no religion

# %%
df.loc[(df['religion'] == 'not_religious'),:]
# Out:
#         participant_ID  age     sex  exercise_hours_weekly  \
# 0        participant_0   36    male                    2.3
# 1        participant_1   42    male                    1.5
# 2        participant_2   29  female                    2.0
# 6        participant_6   63  female                    1.9
# 12      participant_12   41  female                    1.7
# ...                ...  ...     ...                    ...
# 3970  participant_3970   60    male                    1.2
# 3974  participant_3974   58    male                    1.3
# 3976  participant_3976   35    male                    1.2
# 3982  participant_3982   28    male                    2.0
# 3990  participant_3990   24    male                    1.8
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# 0     long-term_relationship   90998               always      town
# 1     long-term_relationship   82144               rarely  suburban
# ...

# %% [markdown]
# #### c) people who live in city

# %%
df.loc[(df['residence'] == 'urban'),:]
# Out:
#         participant_ID  age     sex  exercise_hours_weekly  \
# 7        participant_7   46  female                    1.5
# 11      participant_11   27    male                    0.9
# 16      participant_16   45    male                    2.1
# 18      participant_18   51    male                    1.6
# 19      participant_19   31    male                    1.1
# ...                ...  ...     ...                    ...
# 3993  participant_3993   54    male                    2.0
# 3994  participant_3994   53  female                    1.7
# 3996  participant_3996   31    male                    0.8
# 3997  participant_3997   30  female                    1.3
# 3999  participant_3999   51    male                    1.1
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# 7          legal_partnership   69961               rarely     urban
# 11    long-term_relationship   18428               always     urban
# ...

# %% [markdown]
# #### d) Rural people above the age of 32

# %%
df.loc[(df['residence'] == 'rural') & (df['age'] > 32),:]
# Out:
#         participant_ID  age     sex  exercise_hours_weekly  \
# 3        participant_3   57  female                    1.6
# 5        participant_5   60  female                    2.2
# 20      participant_20   34  female                    1.8
# 46      participant_46   44   other                    1.8
# 47      participant_47   39  female                    2.2
# ...                ...  ...     ...                    ...
# 3975  participant_3975   61  female                    0.5
# 3981  participant_3981   56    male                    1.7
# 3983  participant_3983   66  female                    0.8
# 3986  participant_3986   49  female                    1.0
# 3988  participant_3988   56  female                    1.1
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# 3     long-term_relationship  131726            sometimes     rural
# 5     long-term_relationship  103929               always     rural
# ...

# %% [markdown]
# #### e) Women born in 1970's

# %%
df.loc[(df['sex'] == 'female') & (df['age'] == 52),:]
# Out:
#         participant_ID  age     sex  exercise_hours_weekly  \
# 273    participant_273   52  female                    1.6
# 315    participant_315   52  female                    1.3
# 798    participant_798   52  female                    0.9
# 898    participant_898   52  female                    1.5
# 1060  participant_1060   52  female                    1.8
# 1183  participant_1183   52  female                    2.0
# 1186  participant_1186   52  female                    1.5
# 1196  participant_1196   52  female                    1.3
# 1453  participant_1453   52  female                    2.2
# 1463  participant_1463   52  female                    1.5
# 1495  participant_1495   52  female                    2.0
# 1498  participant_1498   52  female                    1.5
# 1506  participant_1506   52  female                    0.9
# 1551  participant_1551   52  female                    0.2
# 1921  participant_1921   52  female                    0.9
# ...

# %% [markdown]
# #### f) Semiskilled workers who are members of the church

# %%
df.loc[(df['religion'] == 'religious_with_church') & (df['profession'] == 'semi-skilled'),:]
# Out:
#         participant_ID  age     sex  exercise_hours_weekly  \
# 4        participant_4   56    male                    1.4
# 11      participant_11   27    male                    0.9
# 19      participant_19   31    male                    1.1
# 20      participant_20   34  female                    1.8
# 48      participant_48   67    male                    1.8
# ...                ...  ...     ...                    ...
# 3938  participant_3938   38  female                    1.0
# 3964  participant_3964   38    male                    1.8
# 3968  participant_3968   16    male                    1.2
# 3979  participant_3979   55    male                    1.6
# 3993  participant_3993   54    male                    2.0
#
#          relationship_status  income five_a_day_fruit_veg residence  \
# 4     long-term_relationship   55091               rarely  suburban
# 11    long-term_relationship   18428               always     urban
# ...

# %% [markdown]
# ## Question 4

# %% [markdown]
# * It is difficult to differentiate between a data which is pseudo-randomly generated and a real data, however, one strategy would be to look for outliers. In real data outliers are present more than in a fabricated data. Another way to differentiate between the two would be to look for patterns. Our data seems to be almost perfectly uniform - such uniform data is unlikely to arise without some fabrication.
# * We can also compare the average income in the UK with the average income in our dataset. According to statista.com the median annual earnings for full-time employees in the United Kingdom was approximately 31.28 thousand British pounds in 2021 which is way lower than the median in our dataset.

# %% [markdown]
# ## Part B

# %% [markdown]
# * In linear regresssion we can only use numerical variables.
# * we can convert the categorical columns into numerical ones using one hot encoding to use both categorical and numerical data.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df.corr()['positive_mental_health_scale']
# Out:
# age                             0.009850
# exercise_hours_weekly           0.404768
# income                          0.773351
# neuroticism                    -0.000738
# openness                        0.233951
# extraversion                    0.002889
# agreeableness                  -0.028165
# conscientiousness              -0.006150
# GP_visits_last_year             0.007633
# positive_mental_health_scale    1.000000
# Name: positive_mental_health_scale, dtype: float64

# %% [markdown]
# *  income has the highest correlation with positive_mental_health_scale (70%), followed by exercise_hours_weekly 40%

# %% [markdown]
# X contains the independent variables:'exercise_hours_weekly', 'income'

# %%
x = df[['exercise_hours_weekly', 'income']]

# %%
y = df['positive_mental_health_scale']

# %% [markdown]
# * Separate the data into train and test part

# %%
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Prepare Model

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# The above code fits the linear regression model on the training data.

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test,predictions)
plt.show()

# %%
r_sq = model.score(X_test, y_test)
print('coefficient of determination:', round(r_sq,1))
# Out:
# coefficient of determination: 0.6

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, predictions)

# %%
print(f"R2 Score is {round(r2,1)}")
# Out:
# R2 Score is 0.6

# %% [markdown]
# * Past research by Princeton University found that people's day-to-day happiness increases with income up to about $75,000 at which point it tops out
# * In our dataset most people earn between £ 63- £ 106 which implies their mental health (due to income) is optimal, and unlikely to improve significantly based on their financial status alone
# * However, according to new research , experienced well-being rises linearly with log income, with an equally steep slope above 80,000 usd as below it.(Killingsworth, 2021) The findings seem to be consistent with our dataset, which shows a strong, independent association between income and positive mental health. The regression model seems to confirm a positive corelation between all three variables, which suggests that people who earn more, tend to also exercise more, and have better mental health.
# * Moreso, psychical exercise is known to improve physical health as well as mental health(particularly in people who already have problems) . On the other hand , too much exercise can be detrimental. It is unclear due to our limited dataset when the correlation starts to turn negative and how this relates to income.
# * A better understanding of the impact of the two factors on mental health requires research which includes more diverse data (with outliers) from both poor and rich countries.
